# %% [markdown]
# # Data Exploration using Pandas and Numpy

# %% [markdown]
# ### Pandas DataFrame is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal components, the data, rows, and columns.

# %%
#Creating a Pandas DataFrame

# import pandas as pd
import pandas as pd
 
# list of strings
list = ['data', 'exploration', 'using', 'Pandas','Numpy']
 
df = pd.DataFrame(list)
print(df)
# Out:
#              0
# 0         data
# 1  exploration
# 2        using
# 3       Pandas
# 4        Numpy

# %%
# Python code demonstrate creating DataFrame from dict narray / lists By default addresses.
 
import pandas as pd
 
# intialise data of lists.
data = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18]}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
# Selecting a column and a row
# Import pandas package
import pandas as pd
 
# Define a dictionary containing employee data
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 
# Convert the dictionary into DataFrame 
df = pd.DataFrame(data)
 
# select two columns
print(df[['Name', 'Qualification']])
print()

#selecting rows by integer location method

print(df.iloc[3]) #retrieve rows and columns by position
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd
#
# Name                Anuj
# Age                   32
# Address          Kannauj
# Qualification        Phd
# Name: 3, dtype: object

# %% [markdown]
# ### Working with Missing Data
#
# #### Missing Data can occur when no information is provided for one or more items or for a whole unit. Missing Data is a very big problem in real life scenario. Missing Data can also refer to as NA(Not Available) values in pandas.
#
# #### Checking for missing values using isnull() and notnull() : In order to check missing values in Pandas DataFrame, we use a function isnull() and notnull(). Both function help in checking whether a value is NaN or not. These function can also be used in Pandas Series in order to find null values in a series.

# %%
# importing pandas as pd
import pandas as pd
 
# importing numpy as np
import numpy as np
 
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
 
# creating a dataframe from list
df = pd.DataFrame(dict)
 
# using isnull() function  
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %% [markdown]
# ### Filling missing values using fillna(), replace() and interpolate() :
# #### In order to fill null values in a datasets, we use fillna(), replace() and interpolate() function these function replace NaN values with some value of their own. All these function help in filling a null values in datasets of a DataFrame.
# #### Interpolate() function is basically used to fill NA values in the dataframe but it uses various interpolation technique to fill the missing values rather than hard-coding the value.

# %%
# importing pandas as pd
import pandas as pd
 
# importing numpy as np
import numpy as np
 
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
 
# creating a dataframe from dictionary
df = pd.DataFrame(dict)
 
# filling missing value using fillna()  
df.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %% [markdown]
# ### Dropping missing values using dropna() :
# #### In order to drop a null values from a dataframe, we used dropna() function this fuction drop Rows/Columns of datasets with Null values in different ways.

# %%
# importing pandas as pd
import pandas as pd
 
# importing numpy as np
import numpy as np
 
# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}
 
# creating a dataframe from dictionary
df = pd.DataFrame(dict)
   
df

# using dropna() function  
#df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
# importing pandas as pd
import pandas as pd
   
# dictionary of lists
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
  
# creating a dataframe from a dictionary 
df = pd.DataFrame(dict)
 
print(df)
print()
# creating a list of dataframe columns
columns = df
 
for i in columns:
 
    # printing the third element of the column
    print (df[i][2])
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98
#
# sudhir
# M.Tech
# 80

# %% [markdown]
# ### Input data sets can be in various formats (.XLS, .TXT, .CSV, JSON ). In Python, it is easy to load data from any source, due to its simple syntax and availability of predefined libraries, such as Pandas.
#
# ### Pandas features a number of functions for reading tabular data as a Pandas DataFrame object. Below are the common functions that can be used to read data (including read_csv in Pandas):
#
# #### read_csv : read delimited data from the file. Use comma as default delimiter.
#
# #### read_table : read delimited data from the file. Use '\t' (tab) as default delimiter.
#
# #### read_excel: read data from excel file.
#
# #### read_fwf: read data in fixed width column format.
#
# #### read_clipboard: read data from clipboard. Useful for converting tables into webpages.

# %%
#How to load data file(s) using Pandas?

import pandas as pd
#Import Library Pandas

df = pd.read_csv("E:/ColorectalCancer.csv")  #Load csv file

#Reading the dataset in a dataframe using Pandas
print(df.head(3))  #Print first three observations
# Out:
#    ??  Age  Gender  ASA  ASA3  DM  CAD  HF  CVA  CKD  ...  SignetRING  \
# 0   2   52       1    3     1   0    0   0    0    0  ...           0
# 1  21   85       2    2     0   0    1   0    0    0  ...           0
# 2  22   45       2    2     0   0    0   0    0    0  ...           0
#
#    Lymphovascularinvasion  perineural  CT  RT  NACTRT  Death  Interval  \
# 0                       1           0   1   0       0      1     11.76
# 1                       0           0   1   0       0      1      8.38
# 2                       1           0   1   0       0      1      4.76
#
#    Progress  IntervalR
# 0         1       9.86
# 1         1       7.06
# 2         1       2.79
#
# [3 rows x 32 columns]

# %%
df=pd.read_excel("E:/Assessment.xlsx", "Data") # Load Data sheet of excel file
print(df)
# Out:
#                       Timestamp  Score      Registered Email Id only  \
# 0    2022-05-13 11:41:36.480000     11     chaitanya.4863@cgc.edu.in
# 1    2022-05-13 11:41:42.245000     12     manjunathahs.hs@gmail.com
# 2    2022-05-13 11:41:44.050000     13          anilbc@jssateb.ac.in
# 3    2022-05-13 11:41:48.768000     13    manjunathahs@jssateb.ac.in
# 4    2022-05-13 11:41:54.710000     13  vijayakumarahs@jssateb.ac.in
# ..                          ...    ...                           ...
# 367  2022-05-13 20:12:45.787000     13  srilakshmi.mrecw18@gmail.com
# 368  2022-05-13 21:14:02.832000     14     aishwaryag.1216@gmail.com
# 369  2022-05-13 21:38:46.971000     12       pulla.srivani@gmail.com
# 370  2022-05-14 10:00:04.926000     15           subir@silicon.ac.in
# 371  2022-05-14 10:23:44.266000     15      chikkaharshini@gmail.com
#
#     Name of Participant (to be printed on the certificate)  \
# 0                                     Chaitanya Thakur
# ...

# %%
df=pd.read_csv("E:/ColorectalCancertextfile.txt",sep='\t') # Load Data from text file having tab '\t' delimeter print df
print(df)
# Out:
#     ??,Age,Gender,ASA,ASA3,DM,CAD,HF,CVA,CKD,CEA,LogCEA,Laparoscopic,TumorLOC,EA,AnesTime,Log2AT,RBC,AJCC,Liver_Only,Cell_diff,Mucin_TYPE,SignetRING,Lymphovascularinvasion,perineural,CT,RT,NACTRT,Death,Interval,Progress,IntervalR
# 0    2,52,1,3,1,0,0,0,0,0,937,2.97,0,0,0,360,8.49,0...
# 1    21,85,2,2,0,0,1,0,0,0,134,2.13,0,0,1,420,8.71,...
# 2    22,45,2,2,0,0,0,0,0,0,1142,3.06,0,0,0,285,8.15...
# 3    23,57,2,2,0,0,0,0,0,0,31,1.5,0,0,0,450,8.81,1,...
# 4    29,43,1,2,0,1,0,0,0,0,2,0.36,0,0,0,315,8.3,0,1...
# ..                                                 ...
# 994  5158,48,1,3,1,0,0,0,0,0,16,1.2,0,1,0,360,8.49,...
# 995  5162,86,1,3,1,0,0,0,0,0,58,1.76,0,0,0,480,8.91...
# 996  5168,49,2,2,0,0,0,0,0,0,53,1.73,0,0,0,150,7.23...
# 997  5171,76,2,2,0,1,0,0,0,0,77,1.89,1,1,0,300,8.23...
# 998  5172,65,1,2,0,0,0,0,0,0,26,1.41,0,1,0,435,8.76...
#
# [999 rows x 1 columns]

# %%
# How to convert a variable to a different data type?

# 1. Convert numeric variables to string variables and vice versa
numeric_input = 115
string_input = '123'
string_outcome = str(numeric_input) #Converts numeric_input to string_outcome
integer_outcome = int(string_input) #Converts string_input to integer_outcome
float_outcome = float(string_input) #Converts string_input to integer_outcome

print("The string outcome is:", string_outcome)
print("The integer outcome is:", integer_outcome)
print("The float outcome is:", float_outcome)

# 2. Convert character date to Date:
from datetime import datetime
char_date = 'Jan 12 2022 07:58AM' #creating example character date
date_obj = datetime.strptime(char_date, '%b %d %Y %I:%M%p')
print("After converting the character date into date fromat:", date_obj)
# Out:
# The string outcome is: 115
# The integer outcome is: 123
# The float outcome is: 123.0
# After converting the character date into date fromat: 2022-01-12 07:58:00

# %%
# How to transpose a Data set or dataframe using Pandas?

df=pd.read_excel("E:\Lab Sessions\sTUDENT tRAINING\Transpose.xlsx", "Sheet1") # Load Data sheet of excel file EMP 
print(df) 
print() 
result= df.transpose() 
print(result)
# Out:
#    ID Product   Sales
# 0   1     CSE1     56
# 1   1     CSE2     45
# 2   2     CSE3     26
# 3   2     CSE4     78
#
#              0     1     2     3
# ID           1     1     2     2
# Product   CSE1  CSE2  CSE3  CSE4
# Sales       56    45    26    78

# %%
# How to sort a Pandas DataFrame?

#Sorting Pandas Dataframe 

df=pd.read_excel("E:\Lab Sessions\sTUDENT tRAINING\Transpose.xlsx", "Sheet1") 

print(df) 
print() #to add the space between the two outputs

result= df.sort_values(['Sales']) 
print(result)
# Out:
#    ID Product   Sales
# 0   1     CSE1     56
# 1   1     CSE2     45
# 2   2     CSE3     26
# 3   2     CSE4     78
#
#    ID Product   Sales
# 2   2     CSE3     26
# 1   1     CSE2     45
# 0   1     CSE1     56
# 3   2     CSE4     78

# %% [markdown]
# #### Data visualization always helps to understand the data easily.
# #### Python has libraries like matplotlib and seaborn to create multiple graphs effectively. Let’s look at the some of the visualizations to understand below behavior of variable(s) .
#
# #### The distribution of age; Relation between age and sales; and If sales are normally distributed or not?

# %%
#How to create plots (Histogram, Scatter, Box Plot)?

# 1. PLOT HISTOGRAM

import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_excel("E:\Lab Sessions\sTUDENT tRAINING\Transpose.xlsx", "Sheet2") 

#Plots in matplotlib reside within a figure object, use plt.figure to create new figure
fig=plt.figure()

#Create one or more subplots using add_subplot, because you can't create blank figure
ax = fig.add_subplot(1,1,1)

#Variable
ax.hist(df['Age'],bins = 5)

#Labels and Tit
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('#Employee')
plt.show()

# %%
# PLOT Scatter plot

#Plots in matplotlib reside within a figure object, use plt.figure to create new figure fig=plt.figure()

df=pd.read_excel("E:\Lab Sessions\sTUDENT tRAINING\Transpose.xlsx", "Sheet2") 
fig=plt.figure()

#Create one or more subplots using add_subplot, because you can't create blank figure
ax = fig.add_subplot(1,1,1)

#Variable
ax.scatter(df['Age'],df['Sales'])

#Labels and Tit
plt.title('Sales and Age distribution')
plt.xlabel('Age')
plt.ylabel('Sales')
plt.show()

# %%
# Box-plot

import seaborn as sns 
sns.boxplot(df['Age']) 
sns.despine()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### How to generate frequency tables with Pandas?
# #### Frequency Tables can be used to understand the distribution of a categorical variable or n categorical variables using frequency tables.

# %%
#How to generate frequency tables with Pandas?

df=pd.read_excel("E:\Lab Sessions\sTUDENT tRAINING\Transpose.xlsx", "Sheet2")
test= df.groupby(['Gender','BMI'])
test.size()
# Out:
# Gender  BMI
# F       normal         4
#         obesity        4
#         underweight    2
# M       normal         2
#         obesity        5
#         underweight    3
# dtype: int64

# %% [markdown]
# #### How to do sample Data set in Python?
# #### To select sample of a data set, we will use library numpy and random. Sampling of data set always helps to understand data quickly.

# %%
import numpy as np
import pandas as pd
from random import sample

df=pd.read_excel("E:\Lab Sessions\sTUDENT tRAINING\Transpose.xlsx", "Sheet2")
# create random index
rindex = np.array(sample(range(len(df)), 5))

# get 5 random rows from the dataframe df
dfr = df.iloc[rindex]
print(dfr)
# Out:
#    EmpID Gender  Age  Sales      BMI
# 18  E019      M   52    158   normal
# 12  E013      F   45    159  obesity
# 2   E003      F   45    165   normal
# 14  E015      M   68    258  obesity
# 9   E010      F   52    154   normal

# %%
#How to remove duplicate values of a variable in a Pandas Dataframe?

#Remove Duplicate Values based on values of variables "Gender" and "BMI"

df=pd.read_excel("E:\Lab Sessions\sTUDENT tRAINING\Transpose.xlsx", "Sheet2")
rem_dup=df.drop_duplicates(['Gender', 'BMI'])
print(rem_dup)
# Out:
#   EmpID Gender  Age  Sales          BMI
# 0  E001      M   34    123      obesity
# 1  E002      F   25    154  underweight
# 2  E003      F   45    165       normal
# 3  E004      F   23    142      obesity
# 5  E006      M   68    169  underweight
# 6  E007      M   35    253       normal

# %%
#How to group variables in Pandas to calculate count, average, sum?
df=pd.read_excel("E:\Lab Sessions\sTUDENT tRAINING\Transpose.xlsx", "Sheet2")
test= df.groupby(['Gender'])
test.describe()
# Out:
#          Age                                                 Sales         \
#        count  mean        std   min   25%   50%    75%   max count   mean
# Gender
# F       10.0  39.2  13.846781  22.0  27.5  40.0  45.00  65.0  10.0  215.9
# M       10.0  48.7  15.463577  22.0  37.5  49.0  61.75  68.0  10.0  217.0
#
#
#                std    min     25%    50%     75%    max
# Gender
# F       108.136180  142.0  154.00  162.0  234.75  456.0
# M        74.672619  123.0  160.25  208.0  256.75  369.0

# %%
##How to recognize and Treat missing values and outliers in Pandas?

#To identify missing values , we can use dataframe.isnull().
df=pd.read_excel("E:\Lab Sessions\sTUDENT tRAINING\Transpose.xlsx", "Sheet2")
df.isnull()
# Out:
#     EmpID  Gender    Age  Sales    BMI
# 0   False   False  False  False  False
# 1   False   False  False  False  False
# 2   False   False  False  False  False
# 3   False   False  False  False  False
# 4   False   False  False  False  False
# 5   False   False  False  False  False
# 6   False   False  False  False  False
# 7   False   False  False  False  False
# 8   False   False  False  False  False
# 9   False   False  False  False  False
# 10  False   False  False  False  False
# 11  False   False  False  False  False
# 12  False   False  False  False  False
# 13  False   False  False  False  False
# 14  False   False  False  False  False
# 15  False   False  False  False  False
# 16  False   False  False  False  False
# 17  False   False  False  False  False
# 18  False   False  False  False  False
# 19  False   False  False  False  False

# %%
#Assignment: #Example to impute missing values in Age by the mean

import numpy as np
meanAge = np.mean(df.Age)     #Using numpy mean function to calculate the mean value
df.Age = df.Age.fillna(meanAge) #replacing missing values in the DataFrame

# %%
#Assignment: 

#How to merge / join data sets and Pandas dataframes?

#Joining / merging is one of the common operation required to integrate datasets from different sources.
#They can be handled effectively in Pandas using merge function

df_new = pd.merge(df1, df2, how = 'inner', left_index = True, right_index = True) # merges df1 and df2 on index

# By changing how = 'outer', you can do outer join.
# Similarly how = 'left' will do a left join
# You can also specify the columns to join instead of indexes, which are used by default.
